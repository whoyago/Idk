# %%
from controler_vencer import Controlador

ctr = Controlador()
df = ctr.busca_dados()
df.head()
# Out:
#                              Link_Demonstrativo       Id PrefTitulo NrTitulo  \
# 0  https://boletos.adt.com.br/247720_DM_4132122  5386630        DTS  0732271
# 1  https://boletos.adt.com.br/245717_DM_4132125  5386739        DTS  0732274
# 2  https://boletos.adt.com.br/293378_DM_4131981  5387249        DTS  0732418
# 3  https://boletos.adt.com.br/244226_DM_4132546  5387191        DTS  0732584
# 4  https://boletos.adt.com.br/247707_DM_4132551  5386446        DTS  0732589
#
#   ParcelaTitulo IdCliente  MesRefTitulo  AnoRefTitulo           DtEmissao  \
# 0                  247720           6.0        2024.0 2024-06-24 10:59:00
# 1                  245717           6.0        2024.0 2024-06-24 12:24:00
# 2                  293378           6.0        2024.0 2024-06-24 11:02:00
# 3                  244226           6.0        2024.0 2024-06-24 11:09:00
# 4                  247707           6.0        2024.0 2024-06-24 12:32:00
#
# ...

# %%
lini = df.LINK.loc[1:1]
print(*lini)
# Out:
# https://nfe.prefeitura.sp.gov.br/contribuinte/notaprint.aspx?ccm=47687347&nf=4132125&cod=PKMZMGUM

# %%
print(df.shape)
# Out:
# (557, 22)
